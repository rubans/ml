# %%
# !pip install -U magic-pdf[full] #--extra-index-url https://wheels.myhloli.com
# Out:
# ^C
# Looking in indexes: https://pypi.org/simple, https://wheels.myhloli.com
# ...
#   Using cached magic_pdf-0.10.6-py3-none-any.whl (1.0 MB)
# ...
#   Using cached boto3-1.35.87-py3-none-any.whl (139 kB)
# ...
#   Using cached Brotli-1.1.0-cp311-cp311-win_amd64.whl (357 kB)
# ...
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# ...
#   Using cached fast_langdetect-0.2.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached loguru-0.7.3-py3-none-any.whl (61 kB)
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# ...
#   Using cached pydantic-2.7.4-py3-none-any.whl (409 kB)
# ...
#   Using cached pymupdf-1.25.1-cp39-abi3-win_amd64.whl (16.6 MB)
# ...
#   Using cached scikit_learn-1.6.0-cp311-cp311-win_amd64.whl (11.1 MB)
# ...
#   Using cached torch-2.5.1-cp311-cp311-win_amd64.whl (203.1 MB)
# ...
#   Using cached transformers-4.47.1-py3-none-any.whl (10.1 MB)
# ...
#   Using cached pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
# ...
#   Using cached unimernet-0.2.2-py3-none-any.whl (2.3 MB)
# ...

# %%
# !file="/c/Users/ruban/OneDrive/Documents/CV1_GCP.pdf"; magic-pdf -p $file -o /c/Code/llm-function-calling-poc -m auto
#!echo $file
#!magic-pdf -p $file -o /path/to/output_directory -m auto
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !magic-pdf -p "C:\Code\llm-function-calling-poc\original\outlier-or-laggard-divergence-and-convergence-in-the-uks-recent-inflation-performance.pdf" -o c:\Code\llm-function-calling-poc\output -m auto
