# %%
# !pip install markitdown --user
# Out:
# ...
#   Using cached markitdown-0.0.1a3-py3-none-any.whl (16 kB)
# ...
#   Using cached mammoth-1.8.0-py2.py3-none-any.whl (52 kB)
# ...
#   Using cached markdownify-0.14.1-py3-none-any.whl (11 kB)
# ...
#   Using cached openai-1.58.1-py3-none-any.whl (454 kB)
# ...
#   Using cached pathvalidate-3.2.1-py3-none-any.whl (23 kB)
# ...
#   Using cached pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
# ...
#   Using cached python_pptx-1.0.2-py3-none-any.whl (472 kB)
# ...
#   Using cached SpeechRecognition-3.12.0-py3-none-any.whl (32.8 MB)
# ...
#   Using cached youtube_transcript_api-0.6.3-py3-none-any.whl (622 kB)
# ...
#   Using cached cobble-0.1.4-py3-none-any.whl (4.0 kB)
# ...
#   Using cached anyio-4.7.0-py3-none-any.whl (93 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# ...
#   Using cached jiter-0.8.2-cp311-cp311-win_amd64.whl (206 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# ...
#   Using cached cryptography-44.0.0-cp39-abi3-win_amd64.whl (3.2 MB)
# ...

# %%
from markitdown import MarkItDown

md = MarkItDown()
file = "C:\\Users\\ruban\\OneDrive\\Documents\\CV1_GCP.pdf"
result = md.convert(file)
print(result.text_content)
# Out:
# CLOUD / SOLUTIONS ARCHITECT / ENGINEERING LEAD
#
# GU526HX, FLEET, UNITED KINGDOM
#
# 07974727794
#
# RUBAN SIVA
#
# DETAILS
#
# PROFILE
#
# 39 Ryelaw Road
# Gu526hx, Fleet
# United Kingdom
# 07974727794
# rubansiva@hotmail.com
#
# Nationality
# British
#
# LINKS
#
# Medium
#
# LinkedIn
#
# SKILLS
#
# Cloud [GCP, Azure, AWS]
#
# Kubernetes [GKE, Anthos,
# Baremetal, Minikube, Istio]
#
# Back End [C# with Multithreading,
# Python, Rx, Java, NodeJS, ETL,
# Boomi, SSIS]
#
# NoSQL [MongoDB , Firebase,
# BigSQL, DynamoDB]
#
# Relational DB [Microsoft SQL
# Server, Postgres, SnowFlake,
# Oracle, Sybase]
#
# AI/ML Ops [Vertex AI, Vision AI,
# Jupyter Workbooks]
#
# API Services [Flask, REST, WebAPI,
# WCF]
#
# Infrastructure As Code [Terraform,
# Ansible, Packer, Helm]
#
# Scripting [Python, Bash,
# PowerShell]
#
# .NET Core [WebAPI, ASP.NET, MVC]
#
# Front End [ReactJS, HTML5,
# JavaScript, WPF / Silverlight with
# Multithreading & MVVM, Jekyll]
#
# ...
